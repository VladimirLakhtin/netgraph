# %%
import netgraph
import pandas as pd

examples_list = []
for i in range(4):
    sheet_name = 'Example' + str(i + 1)
    df = pd.read_excel('test_inputs.xlsx', sheet_name=sheet_name)
    examples_list.append(df)

# %%
for inp in examples_list:
    img = netgraph.main(inp)

# %% [markdown]
# You can see, that the second graph has the nodes and edges superimposed on each other. So, we try chandged 2 params

# %%
img = netgraph.main(examples_list[1], 0, 0) #nope

# %%
img = netgraph.main(examples_list[1], 0.5, 0.5) # not bad

# %%
img = netgraph.main(examples_list[1], -5, 3.5)

# %% [markdown]
# We have achieved that the lines do not intersect and do not overlap each other. But event C should have been positioned higher
